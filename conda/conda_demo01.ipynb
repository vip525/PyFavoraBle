# %% [markdown]
# # 向量数据库学习

# %%
import dis
from idlelib import query

from aem.kae import cLine
from nltk.corpus.reader import documents
from openai import OpenAI
from openai.types.realtime import realtime_truncation
from statsmodels.tsa.tsatools import vec
from tomlkit import document

# 创建 OpenAI 客户端
client = OpenAI(
    api_key="sk-d37641d8e49c4bf8993677d9c681b241",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
    
)

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %%
def cos_sim(a,b):
    '''余弦距离 -- 越大越相似'''
    return dot(a,b)/(norm(a)*norm(b))

def l2(a,b):
    '''欧式距离 -- 越小越相似'''
    x = np.asarray(a) - np.asarray(b)
    return norm(x)

# %%
# 通用文本向量  : 什么是向量维度：  1536维度 生成1536个浮点数表示：这句话 文本的向量表针，
def get_embeddings(texts,model="text-embedding-v1",dimensions=None):
    '''封装 OpenAI 的Embedding 模型接口'''
    if model == "text-embedding-v1":
        dimensions = None
    if dimensions:
        data = client.embeddings.create(
            input=texts,
            model=model,
            dimensions=dimensions
        ).data
    else:
        data = client.embeddings.create(
            input=texts,
            model=model
        ).data
    return [x.embedding for x in data]

# %%
    test_query = ["聚客AI -用科技力量，构建智能未来！"]
    vec=get_embeddings(test_query)[0]
    print(f"Total dimension:{len(vec)}")
    print(f"First 10 elements:{vec[:10]}")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 test_query = ["聚客AI -用科技力量，构建智能未来！"]
# ----> 2 vec=get_embeddings(test_query)[0]
#       3 print(f"Total dimension:{len(vec)}")
#       4 print(f"First 10 elements:{vec[:10]}")
#
# Cell In[11], line 13, in get_embeddings(texts, model, dimensions)
#       7     data = client.embeddings.create(
#       8         input=texts,
#       9         model=model,
#      10         dimensions=dimensions
#      11     ).data
#      12 else:
# ---> 13     data = client.embeddings.create(
#      14         input=texts,
#      15         model=model
#      16     ).data
#      17 return [x.embedding for x in data]
#
# ...

# %%
    query="国际争端"
    documents = [
    "联合国就苏丹达尔富尔地区大规模暴力事件发出警告",
    "土耳其、芬兰、瑞典与北约代表将继续就瑞典“入约”问题进行谈判",
    "日本岐阜市陆上自卫队射击场内发生枪击事件3人受伤",
    "国家游泳中心(水立方):恢复游泳、嬉水乐园等水上项目目运营",
    "我国首次在空间站开展舱外辐射生物学暴露实验",
                 ]

    query_vec = get_embeddings([query])[0]
    doc_vecs = get_embeddings(documents)

    print("Query与自己的余弦距离:{:.2f}".format(cos_sim(quvery_vec,query_vec)))
    print("Query与Documents的余弦距离:")

    for vec in doc_vecs:
        print(cos_sim(query_vec,vec))
    print()

    print("Query与自己的欧氏距离:{:.2f}".format(l2(querry_vec,query_vec)))
    print("Query与Documents的欧氏距离:")

    for vec in doc_vecs:
        print(l2(query_vec, vec))
